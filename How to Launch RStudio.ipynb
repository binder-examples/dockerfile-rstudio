# %% [markdown]
# # RStudio Demo

# %% [markdown]
# While you can use R in this notebook, this Binder is meant to show an RStudio Demo.
#
# In the dashboard clik on "New" > "RStudio Session".
#
# ![rstudio_demo.png](attachment:rstudio_demo.png)
